# %% [markdown]
# Logistic Regresssion

# %% [markdown]
# ## Background
#
# - We want to learn about Logistic Regression as a method for Classification. In ML and statistics classification is a problem of identifying which set of categories a new observation belongs to, based off of training data.
#
# - Some examples of classification problems :
#
#     - Spam versus “Ham” emails
#     - Loan Default (yes/no)
#     - Disease Diagnosis
#
# All of the above are examples of binary classification.

# %% [markdown]
# - So far we’ve only seen regression problems where we try to predict a continuous value.
# - Although the name may be confusing at first, logistic regression allows us to solve classification problems, where we are trying to predict discrete categories.
# - The convention for binary classification is to have two classes 0 and 1.

# %% [markdown]
# - We can't use normal linear regression model on binary groups, it won't lead to good fit.
# ![image.png](attachment:image.png)

# %% [markdown]
# - If we look at the image above we have on y axis the probability of something belongging to a particular group, 0 means 0% probability that person would pay his/her loan back and on top 1 means that 100% probability that person would pay back his/her loan.
#
# - We mark x-axis as the amount of loan, as per the above model we see that as loan amount goes lower there is a very low probability of loan being paid back, and more payment probability as amount goes up which we can see by yellow dashes.
#
# - On the training data as we can see if we use linear regression then we would get a very bad fit, resulting in predicting probabilities way below 0% and it won't make sense.
#
# - Logical step would be to transfer our linear regression curve to logistic regression curve which looks something like below :
# ![image.png](attachment:image.png)

# %% [markdown]
# - As we notice that logistic regression curve can only go between 0 and 1 and this is the key to understanding classification using logistic regression curve.
# - **The sigmoid (aka Logistic) function takes in any value and outputs it to be between 0 and 1.**
# ![image.png](attachment:image.png)

# %% [markdown]
# - This means we can take our Linear Regression Solution and place it into Sigmoid Function, which looks as follows :
# ![image.png](attachment:image.png)
# - If we take the linear model and put it into the sigmoid function, we are finally able to transform linear regression to a logistic model, meaning it doesn't matter what is the value of linear model output actually is and it will always between 0 and 1, when we place it into logistic model or sigmoid function.

# %% [markdown]
# - Basically all this is done so that probability from 0 to 1 of belongging in the 1 class. Doesn't matter what we put on horizontal x-axis, on y-axis we will get some probability between 0 and 1.
#
# - We can now set a cutoff point, generally taken at 0.5 that anything below cutoff point goes to class 0 and anything above cutoff goes to class 1.
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Review - Logistic Regression
#
# - We use the logistic function to output a value ranging from 0 to 1. Based off of this probability we assign a class. By putting a cutoff point at 0.5, as there are 50-50 probabilities in binary classification for some new observation to be either in class 0 or 1.

# %% [markdown]
# # Model Evaluation
#
# - After you train a logistic regression model on some training data, you will evaluate your model’s performance on some test data.
# - You can use a confusion matrix to evaluate classification models.
# - We can use a confusion matrix to evaluate our model.
# - For example, imagine testing for disease.
# ![image.png](attachment:image.png)

# %% [markdown]
# - What we can infer from the test above is that classifier made a total of 165 predictions and out of those 165 predictions the classifier predicted NO for 55 times total and 110 times it predicted YES.
# - In reality (as we already have labelled test data) 105 patients have the disease and 60 do not have the disease.

# %% [markdown]
# ## Basic Terminology
#
# - True Positives (TP) - Cases where we predicted yes these patients have the disease and in reality they do have the disease. There are 100 such cases where TP = 100.
# - True Negatives (TN) - Cases where we predicted no these patients do not have the disease and in reality they do not have the disease. There are 50 such cases where TN = 50.
# - False Positives (FP) - Cases where we predicted yes these patients have the disease and in reality they do not have the disease. There are 10 such cases where FP = 10. **Type-1 Error.**
# - False Negatives (FN) - Cases where we predicted no these patients do not have the disease while in reality they did have the disease.  There are 5 such cases where FN = 5. **Type-2 Error.**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Accuracy
#
# - Overall how often is our model correct ?
#     - (TP + TN)/TOTAL = (100 + 50)/165 = 0.91
#
# - Overall how often is it incorrect ?
#     - (FP + FN)/TOTAL = (Type-1 Error + Type-2 Error)/TOTAL = 10+5/165 =  0.09
#     - Or because it is probability then we can say that it will maximum be 1 (correct+incorrect). So if correct is 0.91 then incorrect would be total-correct = 1 - 0.91 = 0.09.

# %% [markdown]
# ## Compute precision, recall, F-measure and support for each class
#
#
# - The precision is the ratio tp / (tp + fp) where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier not to label as positive a sample that is negative.
#
#
# - The recall is the ratio tp / (tp + fn) where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
#
# - The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches its best value at 1 and worst score at 0.
#
#
# - The F-beta score weights recall more than precision by a factor of beta. beta == 1.0 means recall and precision are equally important.
#
#
# - The support is the number of occurrences of each class in y_test.
